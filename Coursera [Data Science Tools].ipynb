# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# <b>Leandro Nascimento Lemos </b> <br>Data Scientist/Bioinformatician

# %% [markdown]
# <i> I am interested in data science because I would like to improve my computational skills and solve biological problems. <i>

# %% [markdown]
# <h3> This simple code sum 1 plus 1. <h3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# ![alt text](https://upload.wikimedia.org/wikipedia/commons/4/4f/3_D-Box.jpg)
#
#
#
# <font > <center> www.google.com.br\<font>
#
#
# | Stretch/Untouched | ProbDistribution | Accuracy |
# | --- | --- | --- |
# | Stretched | Gaussian | .843 |
